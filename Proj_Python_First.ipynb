# %% [markdown]
# # 1.Project development motive

# %% [markdown]
# # 2.Project summary

# %% [markdown]
# ## 2-1.Applied programming languages ​​and technologies

# %% [markdown]
# ## 2-2.Expected Effects and Utilization Plans

# %% [markdown]
# # 3.Project production process

# %% [markdown]
# ##3-1.필요한 패키지 import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 3-2.데이터 불러오기

# %%
data = pd.read_csv('/content/drive/MyDrive/BigData/CSV_File/survey lung cancer.csv')

# %%
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %% [markdown]
# > 데이터 칼럼 설명
#
# 총 번호 속성 수:16 인스턴스 수:284 속성 정보: 1. 성별: M(남성), F(여성) 2. 연령: 환자의 연령 3. 흡연: 예=2, 아니요=1. 4. 노란 손가락: 예=2, 아니요=1. 5. 불안: 예=2, 아니요=1. 6. 동료 압력: 예=2, 아니요=1. 7. 만성 질환: 예=2, 아니오=1. 8. 피로: 예=2, 아니요=1. 9. 알레르기: 예=2, 아니요=1. 10. 쌕쌕거림: 예=2, 아니요=1. 11. 알코올: 예=2, 아니요=1. 12. 기침: 예=2, 아니요=1. 13. 숨가쁨: 예=2, 아니요=1. 14. 삼키기 어려움: 예=2, 아니요=1. 15. 흉통: 예=2, 아니오=1. 16. 폐암: 예, 아니요.

# %% [markdown]
# 데이터 칼럼명 변경하기

# %%
data.columns = ['성별', '연령', '흡연여부', '노란손가락', '불안', '동료압력', '만성질환', '피로', '알레르기', '쌕쌕거림', '음주', '기침', '숨가쁨', '연하곤란', '흉통', '폐암']

# %%
data
# Out:
#     성별  연령  흡연여부  노란손가락  불안  동료압력  만성질환  피로  알레르기  쌕쌕거림  음주  기침  숨가쁨  연하곤란  \
# 0    M  69     1      2   2     1     1   2     1     2   2   2    2     2
# 1    M  74     2      1   1     1     2   2     2     1   1   1    2     2
# 2    F  59     1      1   1     2     1   2     1     2   1   2    2     1
# 3    M  63     2      2   2     1     1   1     1     1   2   1    1     2
# 4    F  63     1      2   1     1     1   1     1     2   1   2    2     1
# ..  ..  ..   ...    ...  ..   ...   ...  ..   ...   ...  ..  ..  ...   ...
# 304  F  56     1      1   1     2     2   2     1     1   2   2    2     2
# 305  M  70     2      1   1     1     1   2     2     2   2   2    2     1
# 306  M  58     2      1   1     1     1   1     2     2   2   2    1     1
# 307  M  67     2      1   2     1     1   2     2     1   2   2    2     1
# 308  M  62     1      1   1     2     1   2     2     2   2   1    1     2
#
#      흉통   폐암
# 0     2  YES
# 1     2  YES
# 2     2   NO
# ...

# %% [markdown]
# ## 3-3.데이터 전처리

# %%
# 카테고리 데이터타입의 성별 컬럼 라벨인코더 진행
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

data = le.fit_transform(data['성별'])

# %% [markdown]
# # 4.Conclusions from this project

# %% [markdown]
# # 5.Data source

# %%
cd '/content/drive/MyDrive/BigData/Projects'
# Out:
# /content/drive/MyDrive/BigData/Projects

# %%
# !git config --global user.name 'dydwns9436'
# !git config --global user.email 'dydwns9436@naver.com'

# !git add Proj_Python_First.ipynb

# !git commit -m 'start_2022-06-29/end_2022'
# !git push
# Out:
# [main 90f9b88] start_2022-06-29/end_2022
#  1 file changed, 1 insertion(+)
#  create mode 100644 Proj_Python_First.ipynb
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://dydwns9436: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@github.com/dydwns9436/Projects.git/'
